# %%
import pandas as pd

# %%
df = pd.concat([
    pd.read_csv('Output\Early_Data_Scraped.csv', encoding='utf-8'),
    pd.read_csv('Output\Early_Data_Scraped_Backup_01.csv', encoding='utf-8'),
    pd.read_csv('Output\Early_Data_Scraped_Backup_02.csv', encoding='utf-8')
    ])

# %%
df
# Out:
#         country                            title  \
# 0         Japan                    Data analysts
# 1         Japan                     Data Analyst
# 2         Japan          Data Analyst - データアナリスト
# 3         Japan                Data Analyst - EH
# 4         Japan                Data Analyst - EH
# ...         ...                              ...
# 2495  Indonesia      Remote Junior Web Developer
# 2496  Indonesia                        Developer
# 2497  Indonesia                          Backend
# 2498  Indonesia            Back End (Non-Golang)
# 2499  Indonesia  Opentext CS Migration Developer
#
#                                                 company  \
# 0           \n                Cognizant\n
# 1         \n                Robert Half\n
# 2     \n                Specialized Group\n         ...
# 3     \n                Talisman Corporation\n      ...
# 4     \n                Talisman Corporation\n      ...
# ...                                                 ...
# ...

# %%
df.replace('\s+', ' ', regex=True, inplace=True)

# %%
df
# Out:
#         country                            title                      company  \
# 0         Japan                    Data analysts                   Cognizant
# 1         Japan                     Data Analyst                 Robert Half
# 2         Japan          Data Analyst - データアナリスト           Specialized Group
# 3         Japan                Data Analyst - EH        Talisman Corporation
# 4         Japan                Data Analyst - EH        Talisman Corporation
# ...         ...                              ...                          ...
# 2495  Indonesia      Remote Junior Web Developer                        ERROR
# 2496  Indonesia                        Developer                 STG Digital
# 2497  Indonesia                          Backend                        ERROR
# 2498  Indonesia            Back End (Non-Golang)                        ERROR
# 2499  Indonesia  Opentext CS Migration Developer   Tata Consultancy Services
#
# ...

# %%
df.replace(r"^ +| +$", r"", regex=True, inplace=True)

# %%
df
# Out:
#         country                            title                    company  \
# 0         Japan                    Data analysts                  Cognizant
# 1         Japan                     Data Analyst                Robert Half
# 2         Japan          Data Analyst - データアナリスト          Specialized Group
# 3         Japan                Data Analyst - EH       Talisman Corporation
# 4         Japan                Data Analyst - EH       Talisman Corporation
# ...         ...                              ...                        ...
# 2495  Indonesia      Remote Junior Web Developer                      ERROR
# 2496  Indonesia                        Developer                STG Digital
# 2497  Indonesia                          Backend                      ERROR
# 2498  Indonesia            Back End (Non-Golang)                      ERROR
# 2499  Indonesia  Opentext CS Migration Developer  Tata Consultancy Services
#
# ...

# %%
df.to_csv('Output\Mid_Data_Cleaned.csv', encoding='utf-8', index=False)
